# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_parquet('cruce_data_104i_v1.parquet')

# %%
df.head(2)
# Out:
#           ﻿Operador Servicio_transantiago  Servicio_usuario  Patente  \
# index
# 1454   STP Santiago               F74 00I               104  LBTS-82
# 5732   STP Santiago               F74 00I               104  LBTS-82
#
#       Código_parada_transantiago Código_parada_usuario  \
# index
# 1454              T-34-269-NS-15                   PF2
# 5732              T-14-128-OP-13                  PC37
#
#                       Nombre_parada Hora_inicio_expedición  \
# index
# 1454   Parada / Liceo Juan Mackenna    2020-11-03 10:40:10
# 5732      Parada 8 / (M) Los Leones    2020-11-03 15:45:55
#
#        Hora_fin_expedición Cumplimiento  Secuencia_parada  \
# index
# 1454   2020-11-03 10:44:10           NC                52
# 5732   2020-11-03 16:50:55            C                 1
#
#        Identificador_expedición_día  Distancia_parada_desde_inicio_ruta  \
# index
# 1454                          54408                               17391
# ...

# %%
df.rename(columns={'valor_consc': 'Combustible'}, inplace=True)

# %%
df[['Patente', 'Nombre_parada', 'Secuencia_parada', 'Distancia_parada_desde_inicio_ruta', 'Combustible', 'Identificador_expedición_día', 'Perfil_carga_al_llegar', 'Hora_en_parada', 'fecha_hora_evento', 'Tipo_dia', 'dT_merge']].head(20)
# Out:
#        Patente                                   Nombre_parada  \
# index
# 1454   LBTS-82                    Parada / Liceo Juan Mackenna
# 5732   LBTS-82                       Parada 8 / (M) Los Leones
# 5778   LBTS-82                  Lota / esq. Avenida Los Leones
# 5850   LBTS-82  Avenida Los Leones / esq. Av. Francisco Bilbao
# 5912   LBTS-82           General Artigas / esq.  Avenida Sucre
# 5947   LBTS-82          Chile EspaÃ±a / esq. Alonso de Ercilla
# 5974   LBTS-82                 Parada 3 / IrarrÃ¡zaval - Macul
# 6018   LBTS-82                          Parada 5 / PedagÃ³gico
# 6042   LBTS-82                             Parada / UTEM Macul
# 6072   LBTS-82                   Parada 1 / Colegio San Marcos
# 6105   LBTS-82                 Avenida Macul / esq. Los Olmos
# 6167   LBTS-82                      Parada 1 / Punta de Rieles
# 6191   LBTS-82      Avenida Macul / esq. Av. Escuela AgrÃ­cola
# 6212   LBTS-82          Avenida Macul / esq. Victor Dgo. Silva
# ...

# %%
df.head()
# Out:
#           ﻿Operador Servicio_transantiago  Servicio_usuario  Patente  \
# index
# 1454   STP Santiago               F74 00I               104  LBTS-82
# 5732   STP Santiago               F74 00I               104  LBTS-82
# 5778   STP Santiago               F74 00I               104  LBTS-82
# 5850   STP Santiago               F74 00I               104  LBTS-82
# 5912   STP Santiago               F74 00I               104  LBTS-82
#
#       Código_parada_transantiago Código_parada_usuario  \
# index
# 1454              T-34-269-NS-15                   PF2
# 5732              T-14-128-OP-13                  PC37
# 5778               T-14-124-PO-5                  PC22
# 5850              T-14-123-NS-25                  PC26
# 5912               T-18-155-NS-8                PD1629
#
#                                         Nombre_parada Hora_inicio_expedición  \
# index
# 1454                     Parada / Liceo Juan Mackenna    2020-11-03 10:40:10
# ...
